# %% [markdown]
# # Load Data

# %%
import pandas as pd

# Load the CSV file into a pandas DataFrame
df = pd.read_csv('/NguyenEnergyDataRaw.csv')

# Display the first 5 rows of the DataFrame
display(df)
# Out:
#                Timestamp      Location  sleep_hours  nap_hours  coffee_intake  \
# 0     10/6/2025 11:13:45          Work          6.0        0.0            2.0
# 1     10/6/2025 15:32:46          Work          6.0        0.0            3.0
# 2     10/6/2025 19:10:15        School          6.0        0.0            2.0
# 3     10/7/2025 11:38:06          Work          7.5        0.0            1.0
# 4     10/7/2025 15:02:54          Work          7.0        0.0            2.0
# ..                   ...           ...          ...        ...            ...
# 177  11/23/2025 15:10:01  Home / Other          8.0        0.0            1.0
# 178  11/25/2025 14:27:40          Work          7.0        0.0            1.0
# 179   11/29/2025 8:35:15        School          7.0        0.0            0.5
# 180  11/29/2025 16:38:20        School          7.0        0.0            0.0
# 181  11/30/2025 13:02:59  Home / Other          7.0        2.0            0.0
#
#     exercise_binary  emotion_score  energy_level  product_score
# 0                No              3             4              4
# 1                No              2             3              2
# 2               Yes              4             4              4
# 3                No              3             3              4
# 4                No              2             3              3
# ..              ...            ...           ...            ...
# 177              No              4             4              5
# 178              No              4             3              4
# 179              No              4             4              4
# 180              No              4             4              4
# 181              No              3             2              3
#
# [182 rows x 9 columns]

# %% [markdown]
# # Remove Duplicates

# %%
print(f"DataFrame shape before dropping duplicates: {df.shape}")

# Remove duplicate rows
df.drop_duplicates(inplace=True)

print(f"DataFrame shape after dropping duplicates: {df.shape}")

# Display the head of the DataFrame to show the result
display(df)
# Out:
# DataFrame shape before dropping duplicates: (182, 9)
# DataFrame shape after dropping duplicates: (163, 9)
#                Timestamp      Location  sleep_hours  nap_hours  coffee_intake  \
# 0     10/6/2025 11:13:45          Work          6.0        0.0            2.0
# 1     10/6/2025 15:32:46          Work          6.0        0.0            3.0
# 2     10/6/2025 19:10:15        School          6.0        0.0            2.0
# 3     10/7/2025 11:38:06          Work          7.5        0.0            1.0
# 4     10/7/2025 15:02:54          Work          7.0        0.0            2.0
# ..                   ...           ...          ...        ...            ...
# 177  11/23/2025 15:10:01  Home / Other          8.0        0.0            1.0
# 178  11/25/2025 14:27:40          Work          7.0        0.0            1.0
# 179   11/29/2025 8:35:15        School          7.0        0.0            0.5
# 180  11/29/2025 16:38:20        School          7.0        0.0            0.0
# 181  11/30/2025 13:02:59  Home / Other          7.0        2.0            0.0
#
#     exercise_binary  emotion_score  energy_level  product_score
# 0                No              3             4              4
# 1                No              2             3              2
# 2               Yes              4             4              4
# 3                No              3             3              4
# 4                No              2             3              3
# ..              ...            ...           ...            ...
# 177              No              4             4              5
# 178              No              4             3              4
# 179              No              4             4              4
# 180              No              4             4              4
# 181              No              3             2              3
#
# [163 rows x 9 columns]

# %% [markdown]
# # Catagorical Encode Location feature
# Mappings:
# * Work         -> 1
# * School       -> 2
# * Class        -> 3
# * Home / Other -> 4

# %%
# Create a copy of the original DataFrame
df_new = df.copy()

mapping = {
    'Work': 1,
    'School': 2,
    'Class': 3,
    'Home / Other': 4
}
df_new['Location'] = df_new['Location'].replace(mapping)

# Display the head of the new DataFrame to show the updated 'Location' column
display(df_new)
# Out:
# /tmp/ipython-input-3827681194.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_new['Location'] = df_new['Location'].replace(mapping)
#                Timestamp  Location  sleep_hours  nap_hours  coffee_intake  \
# 0     10/6/2025 11:13:45         1          6.0        0.0            2.0
# 1     10/6/2025 15:32:46         1          6.0        0.0            3.0
# 2     10/6/2025 19:10:15         2          6.0        0.0            2.0
# 3     10/7/2025 11:38:06         1          7.5        0.0            1.0
# 4     10/7/2025 15:02:54         1          7.0        0.0            2.0
# ..                   ...       ...          ...        ...            ...
# 177  11/23/2025 15:10:01         4          8.0        0.0            1.0
# 178  11/25/2025 14:27:40         1          7.0        0.0            1.0
# 179   11/29/2025 8:35:15         2          7.0        0.0            0.5
# 180  11/29/2025 16:38:20         2          7.0        0.0            0.0
# 181  11/30/2025 13:02:59         4          7.0        2.0            0.0
#
#     exercise_binary  emotion_score  energy_level  product_score
# 0                No              3             4              4
# 1                No              2             3              2
# 2               Yes              4             4              4
# 3                No              3             3              4
# 4                No              2             3              3
# ..              ...            ...           ...            ...
# 177              No              4             4              5
# 178              No              4             3              4
# 179              No              4             4              4
# 180              No              4             4              4
# 181              No              3             2              3
#
# [163 rows x 9 columns]

# %% [markdown]
# # Categorical encoding exercise_binary column
# Mapping of "Have I exercised yet?"
# * No -> 0
# * Yes -> 1

# %%
binary_mapping = {
    'No': 0,
    'Yes': 1
}
df_new['exercise_binary'] = df_new['exercise_binary'].replace(binary_mapping)

# Display the head of the DataFrame to show the updated 'exercise_binary' column
display(df_new)
# Out:
# /tmp/ipython-input-3520161826.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df_new['exercise_binary'] = df_new['exercise_binary'].replace(binary_mapping)
#                Timestamp  Location  sleep_hours  nap_hours  coffee_intake  \
# 0     10/6/2025 11:13:45         1          6.0        0.0            2.0
# 1     10/6/2025 15:32:46         1          6.0        0.0            3.0
# 2     10/6/2025 19:10:15         2          6.0        0.0            2.0
# 3     10/7/2025 11:38:06         1          7.5        0.0            1.0
# 4     10/7/2025 15:02:54         1          7.0        0.0            2.0
# ..                   ...       ...          ...        ...            ...
# 177  11/23/2025 15:10:01         4          8.0        0.0            1.0
# 178  11/25/2025 14:27:40         1          7.0        0.0            1.0
# 179   11/29/2025 8:35:15         2          7.0        0.0            0.5
# 180  11/29/2025 16:38:20         2          7.0        0.0            0.0
# 181  11/30/2025 13:02:59         4          7.0        2.0            0.0
#
#      exercise_binary  emotion_score  energy_level  product_score
# 0                  0              3             4              4
# 1                  0              2             3              2
# 2                  1              4             4              4
# 3                  0              3             3              4
# 4                  0              2             3              3
# ..               ...            ...           ...            ...
# 177                0              4             4              5
# 178                0              4             3              4
# 179                0              4             4              4
# 180                0              4             4              4
# 181                0              3             2              3
#
# [163 rows x 9 columns]

# %% [markdown]
# # Convert TimeStamp feature to Hour of Day
# * Drop the date from the timestamp
# * Convert to date time objects

# %%
# Reset the 'Timestamp' column in df_new to its original string format from df
df_new['Timestamp'] = df['Timestamp'].copy()

# Convert 'Timestamp' column to datetime objects, inferring mixed formats
df_new['Timestamp'] = pd.to_datetime(df_new['Timestamp'], format='mixed')

# Extract only the time part from the 'Timestamp' column
df_new['Timestamp'] = df_new['Timestamp'].dt.time

# Extract the hour from the original Timestamp column into a new column
df_new['hour_of_day'] = pd.to_datetime(df['Timestamp'], format='mixed').dt.hour

# Drop the original Timestamp column
df_new = df_new.drop('Timestamp', axis=1)

# Display the updated DataFrame
display(df_new.head())
# Out:
#    Location  sleep_hours  nap_hours  coffee_intake  exercise_binary  \
# 0         1          6.0        0.0            2.0                0
# 1         1          6.0        0.0            3.0                0
# 2         2          6.0        0.0            2.0                1
# 3         1          7.5        0.0            1.0                0
# 4         1          7.0        0.0            2.0                0
#
#    emotion_score  energy_level  product_score  hour_of_day
# 0              3             4              4           11
# 1              2             3              2           15
# 2              4             4              4           19
# 3              3             3              4           11
# 4              2             3              3           15

# %% [markdown]
# # Save to new CSV

# %%
df_new.to_csv('/NguyenEnergyDataCleaned.csv', index=False)
print("DataFrame 'df_new' successfully saved to 'NguyenEnergyDataCleaned.csv'")
# Out:
# DataFrame 'df_new' successfully saved to 'NguyenEnergyDataCleaned.csv'
